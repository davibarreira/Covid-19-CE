# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
pd.options.display.max_columns = 50

# %%
df = pd.read_csv("dados/casos_coronavirus.csv",encoding='latin')

# %%
df.columns
# Out:
# Index(['bairroPaciente', 'classificacaoEstadoSivep', 'codigoMunicipioPaciente',
#        'codigoPaciente', 'comorbidadeAsmaSivep',
#        'comorbidadeCardiovascularSivep', 'comorbidadeDiabetesSivep',
#        'comorbidadeHematologiaSivep', 'comorbidadeImunodeficienciaSivep',
#        'comorbidadeNeurologiaSivep', 'comorbidadeObesidadeSivep',
#        'comorbidadePneumopatiaSivep', 'comorbidadePuerperaSivep',
#        'comorbidadeRenalSivep', 'comorbidadeSindromeDownSivep',
#        'dataEntradaUtisSvep', 'dataEvolucaoCasoSivep', 'dataInicioSintomas',
#        'dataInternacaoSivep', 'dataNotificacao', 'dataObito',
#        'dataResultadoExame', 'dataSaidaUtisSvep', 'dataSolicitacaoExame',
#        'estadoPaciente', 'evolucaoCasoSivep', 'idSivep', 'idadePaciente',
#        'municipioPaciente', 'obitoConfirmado', 'paisPaciente',
#        'resultadoFinalExame', 'sexoPaciente'],
#       dtype='object')

# %%
dcasos = df[['codigoPaciente','sexoPaciente','municipioPaciente','resultadoFinalExame','dataInicioSintomas','dataNotificacao','dataResultadoExame']]
# dcasos[dcasos['municipioPaciente']=='FORTALEZA'].pivot_table(index=['resultadoFinalExame','municipioPaciente'],aggfunc='count')
# dcasos_aux = dcasos.pivot_table(index=['resultadoFinalExame','municipioPaciente','codigoPaciente'],aggfunc='count').reset_index()

dcasos['dataCasoComputado'] = dcasos['dataInicioSintomas']
dcasos['dataCasoComputado'].fillna(dcasos['dataNotificacao'],inplace=True)
dcasos['dataCasoComputado'].fillna(dcasos['dataResultadoExame'],inplace=True)
dcasos['ano'] = dcasos['dataCasoComputado']
dcasos['ano'] = dcasos['ano'][pd.notnull(dcasos['ano'])].apply(lambda x: int(x[0:4]))
# dcasos['dataCasoComputado'] = dcasos.loc[dcasos['ano']==202,'dataCasoComputado'].apply(lambda x: "2020"+x[4:])
dcasos.loc[dcasos['ano']==202,'dataCasoComputado'] = dcasos.loc[dcasos['ano']==202,'dataCasoComputado'].apply(lambda x: "2020"+x[4:])
dcasos.loc[dcasos['ano']==202,'ano'] = 2020

pd.to_datetime(dcasos['dataCasoComputado'])
# Out:
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# 0              NaT
# 1              NaT
# 2       2020-03-20
# 3       2020-03-29
# 4       2020-03-24
#            ...
# 20130   2020-03-23
# 20131   2020-03-26
# 20132   2020-03-21
# 20133   2020-03-25
# 20134   2020-03-20
# Name: dataCasoComputado, Length: 20135, dtype: datetime64[ns]

# %%
# Out:
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/pandas/core/generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /home/davisbarreira/anaconda3/envs/covid19ce/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
dcasos[dcasos['ano']==202]
# "2020"+dcasos.iloc[19922]['dataResultadoExame'][4:]
# dcasos.loc[dcasos['ano']==202,'dataCasoComputado'].apply(lambda x: "2020"+x[4:])
# dcasos
# Out:
#                          codigoPaciente sexoPaciente municipioPaciente  \
# 0      7e2e030aeb821dc31333e4590b9d83f5     FEMININO               NaN
# 1      438e3e58edd976ac46cec06e8c17850e    MASCULINO               NaN
# 2      583f9182bedd38b50326e1d866bdf4c0    MASCULINO               NaN
# 3      1aebb3cc91e52b37e2a3d54e05eff098    MASCULINO               NaN
# 4      0acfa773ece16ff9920cf5616f73ffe8     FEMININO               NaN
# ...                                 ...          ...               ...
# 20130  b90376e69d28b7fed86cf9a8d3d7f32a     FEMININO               NaN
# 20131  e22cf245b7afae61b26e4885d4d1dd3e     FEMININO               NaN
# 20132  979bbc2ae610c9dcb53642c1ad4926fb     FEMININO               NaN
# 20133  fae5a501f57baabfc22aa349a64046cb    MASCULINO               NaN
# 20134  676f0f92c806380d7d2bca970ce909df     FEMININO               NaN
#
#       resultadoFinalExame dataInicioSintomas dataNotificacao  \
# 0                Negativo                NaN             NaN
# 1                Negativo                NaN             NaN
# 2                Negativo                NaN             NaN
# 3                Negativo                NaN             NaN
# 4                Negativo                NaN             NaN
# ...                   ...                ...             ...
# 20130            Negativo                NaN             NaN
# 20131            Negativo                NaN             NaN
# 20132            Negativo                NaN             NaN
# 20133            Negativo                NaN             NaN
# 20134            Negativo                NaN             NaN
#
#           dataResultadoExame      dataCasoComputado     ano
# 0                        NaN                    NaN     NaN
# 1                        NaN                    NaN     NaN
# 2      2020-03-20 00:00:00.0  2020-03-20 00:00:00.0  2020.0
# 3      2020-03-29 00:00:00.0  2020-03-29 00:00:00.0  2020.0
# 4      2020-03-24 00:00:00.0  2020-03-24 00:00:00.0  2020.0
# ...                      ...                    ...     ...
# 20130  2020-03-23 00:00:00.0  2020-03-23 00:00:00.0  2020.0
# 20131  2020-03-26 00:00:00.0  2020-03-26 00:00:00.0  2020.0
# 20132  2020-03-21 00:00:00.0  2020-03-21 00:00:00.0  2020.0
# 20133  2020-03-25 00:00:00.0  2020-03-25 00:00:00.0  2020.0
# 20134  2020-03-20 00:00:00.0  2020-03-20 00:00:00.0  2020.0
#
# [20135 rows x 9 columns]

# %%
# pd.isna(dcasos['dataInicioSintomas'])
# dcasos = dcasos[['dataInicioSintomas','dataNotificacao','dataResultadoExame']].fillna("")
# dcasos['dataCasoComputado'] = dcasos['dataInicioSintomas'] + dcasos['dataNotificacao'] + dcasos['dataResultadoExame']

# %%
dcasos[dcasos['municipioPaciente']=='FORTALEZA'].pivot_table(index=['resultadoFinalExame','municipioPaciente'],aggfunc=lambda x: len(x.unique()))
# Out:
#                                        codigoPaciente  dataInicioSintomas  \
# resultadoFinalExame municipioPaciente
# Em Análise          FORTALEZA                    3009                  46
# Inconclusivo        FORTALEZA                      62                  15
# Negativo            FORTALEZA                    4036                  44
# Positivo            FORTALEZA                    1795                  36
#
#                                        dataNotificacao  dataResultadoExame  \
# resultadoFinalExame municipioPaciente
# Em Análise          FORTALEZA                      193                   2
# Inconclusivo        FORTALEZA                       29                  17
# Negativo            FORTALEZA                     1278                  44
# Positivo            FORTALEZA                      411                  31
#
#                                        sexoPaciente
# resultadoFinalExame municipioPaciente
# Em Análise          FORTALEZA                     5
# Inconclusivo        FORTALEZA                     2
# Negativo            FORTALEZA                     4
# Positivo            FORTALEZA                     4

# %%
dcasos[pd.isna(dcasos['codigoPaciente'])]
# Out:
# Empty DataFrame
# Columns: [codigoPaciente, sexoPaciente, municipioPaciente, resultadoFinalExame, dataInicioSintomas, dataNotificacao, dataResultadoExame]
# Index: []

# %%
dcasos[dcasos['municipioPaciente']=='FORTALEZA']
# Out:
#                          codigoPaciente sexoPaciente municipioPaciente  \
# 7      6a6b81967f5d385b4c9cb551a4c88040    MASCULINO         FORTALEZA
# 8      3baade2ba4ae23f96c4d594d7f3f00fb     FEMININO         FORTALEZA
# 9      942078a950f3049737afcd4b0fc2b94f     FEMININO         FORTALEZA
# 10     f00aab72ee0a18c2045d6ddcd968c3b3    MASCULINO         FORTALEZA
# 12     da42dbe5d4e8c8565acc62ea6de0a2c2     FEMININO         FORTALEZA
# ...                                 ...          ...               ...
# 20092  3eac6bc0a69a96ff35e284ee76007c58    MASCULINO         FORTALEZA
# 20093  c430ecc534ef015cc114b3665be9df6c    MASCULINO         FORTALEZA
# 20094  f765e47007d6d83d0976c6683abdc6d0    MASCULINO         FORTALEZA
# 20105  f84cbafb1af73d1aa46e31903b15d338     FEMININO         FORTALEZA
# 20106  1b939a3d06945c0d55df0c741f9f6db4     FEMININO         FORTALEZA
#
#       resultadoFinalExame     dataInicioSintomas        dataNotificacao  \
# 7              Em Análise  2020-03-29 00:00:00.0  2020-03-31 00:00:00.0
# 8              Em Análise  2020-03-30 00:00:00.0  2020-03-31 00:00:00.0
# 9              Em Análise  2020-03-30 00:00:00.0  2020-03-31 00:00:00.0
# 10             Em Análise  2020-03-18 00:00:00.0  2020-04-01 00:00:00.0
# 12             Em Análise  2020-03-18 00:00:00.0  2020-03-31 00:00:00.0
# ...                   ...                    ...                    ...
# 20092            Negativo                    NaN                    NaN
# 20093            Negativo                    NaN                    NaN
# 20094            Negativo                    NaN                    NaN
# 20105            Negativo                    NaN                    NaN
# 20106            Negativo                    NaN                    NaN
#
#           dataResultadoExame
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 12                       NaN
# ...                      ...
# 20092  2020-04-10 00:00:00.0
# 20093  2020-04-10 00:00:00.0
# 20094  2020-04-10 00:00:00.0
# 20105  2020-04-10 00:00:00.0
# 20106  2020-04-10 00:00:00.0
#
# [12540 rows x 7 columns]

# %%
df.pivot_table(index=['resultadoFinalExame'],aggfunc='count')
# Out:
#                      bairroPaciente  classificacaoEstadoSivep  \
# resultadoFinalExame
# Em Análise                     4187                       225
# Inconclusivo                     85                         6
# Negativo                       6088                       236
# Positivo                       2106                       258
#
#                      codigoMunicipioPaciente  codigoPaciente  \
# resultadoFinalExame
# Em Análise                              4611            4673
# Inconclusivo                              85              85
# Negativo                                5411            6216
# Positivo                                2116            2152
#
#                      comorbidadeAsmaSivep  comorbidadeCardiovascularSivep  \
# resultadoFinalExame
# Em Análise                             97                             141
# Inconclusivo                            1                               2
# Negativo                               76                             117
# Positivo                               80                             235
#
#                      comorbidadeDiabetesSivep  comorbidadeHematologiaSivep  \
# resultadoFinalExame
# Em Análise                                133                           96
# Inconclusivo                                1                            1
# Negativo                                  102                           72
# Positivo                                  223                           79
#
#                      comorbidadeImunodeficienciaSivep  \
# resultadoFinalExame
# Em Análise                                        117
# Inconclusivo                                        1
# Negativo                                           88
# Positivo                                          189
#
#                      comorbidadeNeurologiaSivep  comorbidadeObesidadeSivep  \
# resultadoFinalExame
# Em Análise                                  115                         99
# Inconclusivo                                  1                          1
# Negativo                                     87                         74
# Positivo                                    187                         82
#
#                      comorbidadePneumopatiaSivep  comorbidadePuerperaSivep  \
# resultadoFinalExame
# Em Análise                                   115                        95
# Inconclusivo                                   1                         1
# Negativo                                      90                        68
# Positivo                                     192                        71
#
#                      comorbidadeRenalSivep  comorbidadeSindromeDownSivep  \
# resultadoFinalExame
# Em Análise                             107                            94
# Inconclusivo                             0                             1
# Negativo                                83                            72
# Positivo                               185                            79
#
#                      dataEntradaUtisSvep  dataEvolucaoCasoSivep  \
# resultadoFinalExame
# Em Análise                            50                     22
# Inconclusivo                           2                      2
# Negativo                              50                     34
# Positivo                             114                     77
#
#                      dataInicioSintomas  dataInternacaoSivep  dataNotificacao  \
# resultadoFinalExame
# Em Análise                         2198                  189             2323
# Inconclusivo                         25                    6               53
# Negativo                           1113                  204             3337
# Positivo                            713                  235             1346
#
#                      dataObito  dataResultadoExame  dataSaidaUtisSvep  \
# resultadoFinalExame
# Em Análise                  24                  13                  9
# Inconclusivo                 0                  82                  2
# Negativo                    12                5677                 12
# Positivo                   148                1952                 26
#
#                      dataSolicitacaoExame  estadoPaciente  evolucaoCasoSivep  \
# resultadoFinalExame
# Em Análise                           3733            4628                 29
# Inconclusivo                           63              85                  2
# Negativo                             4181            5447                 36
# Positivo                             1310            2120                 96
#
#                      idSivep  idadePaciente  municipioPaciente  \
# resultadoFinalExame
# Em Análise               225           4611               4628
# Inconclusivo               6             77                 85
# Negativo                 236           6009               5444
# Positivo                 258           2103               2120
#
#                      obitoConfirmado  paisPaciente  sexoPaciente
# resultadoFinalExame
# Em Análise                        25          3820          4673
# Inconclusivo                       0            66            85
# Negativo                          14          4645          6214
# Positivo                         147          1520          2152
